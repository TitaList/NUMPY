# %% [markdown]
# # General Numpy

# %%
import numpy as np

# %%
#### Arrays in Numpy
- Homogeneous - array has to only contain one data type 
- All elements of array MUST be the same data type
- The shape must be rectangula

# %%
#single dimentinal array 
a = np.array([1,2,3,4,5,6,7])

print(a)
# Out:
# [1 2 3 4 5 6 7]

# %%
a[-1 : 0 : 1]
# Out:
# array([], dtype=int64)

# %%
# All rows now have 4 elements
multiDimArr = np.array([[1, 2, 3, 4], [5, 6, 7, 0], [8, 9, 10, 11]])
print(multiDimArr)
# Out:
# [[ 1  2  3  4]
#  [ 5  6  7  0]
#  [ 8  9 10 11]]

# %%
# ** differnt from list
multiDimArr[2, 2]
# Out:
# np.int64(10)

# %%
a.dtype
# Out:
# dtype('int64')
